# %%
import numpy as np
import torch

from ViscousBurgersExact import burgers_gt
from visualization import *
from main import *
from used_attacks import regression_PGD

''' Settings and seeds '''

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("device:", device)

if device == 'cuda': 
    print(torch.cuda.get_device_name()) 
    
''' test dataset '''

x = np.linspace(-1, 1, 256)
t = np.linspace(0, .99, 100)
X, T = np.meshgrid(x,t)
U_gt = burgers_gt(t*np.pi)

x_test = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))
u_test = U_gt.flatten('F')[:,None]
print("test dataset:", x_test.shape, '\n')

''' model '''

layers = np.array([2,20,20,20,20,20,20,20,20,1]) #8 hidden layers
PINN = sequential_model(layers, device)
PINN.to(device)
print(PINN)
plot_u(U_gt, x, t, title="$u(x)$")
# Out:
# device: cpu
# test dataset: (25600, 2)
#
# sequential_model(
#   (activation): Tanh()
#   (loss_function): MSELoss()
#   (linears): ModuleList(
#     (0): Linear(in_features=2, out_features=20, bias=True)
#     (1): Linear(in_features=20, out_features=20, bias=True)
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Linear(in_features=20, out_features=20, bias=True)
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Linear(in_features=20, out_features=20, bias=True)
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Linear(in_features=20, out_features=20, bias=True)
#     (8): Linear(in_features=20, out_features=1, bias=True)
#   )
# )
# <AxesSubplot: title={'center': '$u(x)$'}, xlabel='$t$', ylabel='$x$'>

# %%
def generate_attack_samples(model, device, x_train, N0, n_samples=1000, \
    lb=[-1,0], ub=[1,1], steps=20, eps=1e-1, eta=2e-2, m=1):
    
    attack = regression_PGD(model, lb=lb, ub=ub, steps=steps, eps=eps, eta=eta)
    x_adv = attack.attack(x_train).cpu().detach().numpy()
    
    if x_adv.shape[0] > N0 + (m+1)*n_samples:
        x_adv = np.vstack([x_adv[:N0,:] ,x_adv[-(m+1)*n_samples:,:]])

    f_adv_pred = np.abs(model.function(x_adv).squeeze().cpu().detach().numpy())
    index = np.argsort(f_adv_pred)[::-1][:n_samples]
    x_adv = x_adv[index,:]
    f_adv_pred = f_adv_pred[index]
    
    plot_samples(x_adv, f_adv_pred)
    
    return x_adv


def retrain(model, x_train, x_adv, x_boundary, u_boundary, x_test, u_test, U_gt, epoch=1e5):
    
    x_train_temp = np.vstack([x_train, x_adv])
    
    f_test_pred = np.abs(model.function(x_test).squeeze().cpu().detach().numpy())
    plot_u(f_test_pred.reshape(X.shape).T, x, t, log=True, title="test $r(x;theta)$")

    model.iter = 0
    optimizer = torch.optim.Adam(PINN.parameters(), lr=0.0001)
    model.train_model_adam(optimizer, x_boundary, u_boundary, x_train_temp, epoch)
                           
    rmse, u_pred = model.test(x_test, u_test)
    print('Test RMSE: %.5f'  % (rmse))
                           
    plot_u_x(u_pred.reshape(X.shape).T, U_gt, x, t)
    plot_u(np.abs(u_pred.reshape(X.shape).T-U_gt), x, t, log=True, title="$|u(x;theta)-u(x)|$")

# %%
''' k=0 '''
N0 = 500
x_train, x_boundary, u_boundary = training_data_latin_hypercube(X, T, U_gt, N_inner=N0)
retrain(PINN, optimizer, x_train, np.array([]).reshape((0,2)), \
    x_boundary, u_boundary, x_test, u_test, U_gt, epoch=1e5)
# Out:
# 1000 tensor(0.0881, grad_fn=<AddBackward0>)
# 2000 tensor(0.0564, grad_fn=<AddBackward0>)
# 3000 tensor(0.0339, grad_fn=<AddBackward0>)
# 4000 tensor(0.0225, grad_fn=<AddBackward0>)
# 5000 tensor(0.0182, grad_fn=<AddBackward0>)
# 6000 tensor(0.0162, grad_fn=<AddBackward0>)
# 7000 tensor(0.0149, grad_fn=<AddBackward0>)
# 8000 tensor(0.0144, grad_fn=<AddBackward0>)
# 9000 tensor(0.0139, grad_fn=<AddBackward0>)
# 10000 tensor(0.0136, grad_fn=<AddBackward0>)
# 11000 tensor(0.0134, grad_fn=<AddBackward0>)
# 12000 tensor(0.0131, grad_fn=<AddBackward0>)
# 13000 tensor(0.0128, grad_fn=<AddBackward0>)
# 14000 tensor(0.0123, grad_fn=<AddBackward0>)
# 15000 tensor(0.0125, grad_fn=<AddBackward0>)
# 16000 tensor(0.0117, grad_fn=<AddBackward0>)
# 17000 tensor(0.0114, grad_fn=<AddBackward0>)
# 18000 tensor(0.0108, grad_fn=<AddBackward0>)
# 19000 tensor(0.0105, grad_fn=<AddBackward0>)
# 20000 tensor(0.0102, grad_fn=<AddBackward0>)
# 21000 tensor(0.0083, grad_fn=<AddBackward0>)
# 22000 tensor(0.0077, grad_fn=<AddBackward0>)
# 23000 tensor(0.0072, grad_fn=<AddBackward0>)
# 24000 tensor(0.0070, grad_fn=<AddBackward0>)
# 25000 tensor(0.0067, grad_fn=<AddBackward0>)
# 26000 tensor(0.0065, grad_fn=<AddBackward0>)
# 27000 tensor(0.0063, grad_fn=<AddBackward0>)
# 28000 tensor(0.0065, grad_fn=<AddBackward0>)
# 29000 tensor(0.0054, grad_fn=<AddBackward0>)
# 30000 tensor(0.0044, grad_fn=<AddBackward0>)
# 31000 tensor(0.0040, grad_fn=<AddBackward0>)
# 32000 tensor(0.0037, grad_fn=<AddBackward0>)
# 33000 tensor(0.0035, grad_fn=<AddBackward0>)
# 34000 tensor(0.0035, grad_fn=<AddBackward0>)
# 35000 tensor(0.0030, grad_fn=<AddBackward0>)
# 36000 tensor(0.0029, grad_fn=<AddBackward0>)
# 37000 tensor(0.0027, grad_fn=<AddBackward0>)
# 38000 tensor(0.0027, grad_fn=<AddBackward0>)
# 39000 tensor(0.0026, grad_fn=<AddBackward0>)
# 40000 tensor(0.0024, grad_fn=<AddBackward0>)
# 41000 tensor(0.0023, grad_fn=<AddBackward0>)
# 42000 tensor(0.0022, grad_fn=<AddBackward0>)
# 43000 tensor(0.0038, grad_fn=<AddBackward0>)
# 44000 tensor(0.0021, grad_fn=<AddBackward0>)
# 45000 tensor(0.0021, grad_fn=<AddBackward0>)
# 46000 tensor(0.0033, grad_fn=<AddBackward0>)
# 47000 tensor(0.0020, grad_fn=<AddBackward0>)
# 48000 tensor(0.0023, grad_fn=<AddBackward0>)
# 49000 tensor(0.0019, grad_fn=<AddBackward0>)
# 50000 tensor(0.0019, grad_fn=<AddBackward0>)
# 51000 tensor(0.0017, grad_fn=<AddBackward0>)
# 52000 tensor(0.0020, grad_fn=<AddBackward0>)
# 53000 tensor(0.0016, grad_fn=<AddBackward0>)
# 54000 tensor(0.0016, grad_fn=<AddBackward0>)
# 55000 tensor(0.0016, grad_fn=<AddBackward0>)
# 56000 tensor(0.0015, grad_fn=<AddBackward0>)
# 57000 tensor(0.0014, grad_fn=<AddBackward0>)
# 58000 tensor(0.0015, grad_fn=<AddBackward0>)
# 59000 tensor(0.0018, grad_fn=<AddBackward0>)
# 60000 tensor(0.0014, grad_fn=<AddBackward0>)
# 61000 tensor(0.0013, grad_fn=<AddBackward0>)
# 62000 tensor(0.0013, grad_fn=<AddBackward0>)
# 63000 tensor(0.0012, grad_fn=<AddBackward0>)
# 64000 tensor(0.0015, grad_fn=<AddBackward0>)
# 65000 tensor(0.0012, grad_fn=<AddBackward0>)
# 66000 tensor(0.0011, grad_fn=<AddBackward0>)
# 67000 tensor(0.0013, grad_fn=<AddBackward0>)
# 68000 tensor(0.0012, grad_fn=<AddBackward0>)
# 69000 tensor(0.0011, grad_fn=<AddBackward0>)
# 70000 tensor(0.0012, grad_fn=<AddBackward0>)
# 71000 tensor(0.0010, grad_fn=<AddBackward0>)
# 72000 tensor(0.0010, grad_fn=<AddBackward0>)
# 73000 tensor(0.0011, grad_fn=<AddBackward0>)
# 74000 tensor(0.0009, grad_fn=<AddBackward0>)
# 75000 tensor(0.0010, grad_fn=<AddBackward0>)
# 76000 tensor(0.0009, grad_fn=<AddBackward0>)
# 77000 tensor(0.0009, grad_fn=<AddBackward0>)
# 78000 tensor(0.0010, grad_fn=<AddBackward0>)
# 79000 tensor(0.0008, grad_fn=<AddBackward0>)
# 80000 tensor(0.0009, grad_fn=<AddBackward0>)
# 81000 tensor(0.0048, grad_fn=<AddBackward0>)
# 82000 tensor(0.0020, grad_fn=<AddBackward0>)
# 83000 tensor(0.0014, grad_fn=<AddBackward0>)
# 84000 tensor(0.0012, grad_fn=<AddBackward0>)
# 85000 tensor(0.0010, grad_fn=<AddBackward0>)
# 86000 tensor(0.0009, grad_fn=<AddBackward0>)
# 87000 tensor(0.0008, grad_fn=<AddBackward0>)
# 88000 tensor(0.0007, grad_fn=<AddBackward0>)
# 89000 tensor(0.0006, grad_fn=<AddBackward0>)
# 90000 tensor(0.0006, grad_fn=<AddBackward0>)
# 91000 tensor(0.0004, grad_fn=<AddBackward0>)
# 92000 tensor(0.0004, grad_fn=<AddBackward0>)
# 93000 tensor(0.0003, grad_fn=<AddBackward0>)
# 94000 tensor(0.0003, grad_fn=<AddBackward0>)
# 95000 tensor(0.0003, grad_fn=<AddBackward0>)
# 96000 tensor(0.0003, grad_fn=<AddBackward0>)
# 97000 tensor(0.0002, grad_fn=<AddBackward0>)
# 98000 tensor(0.0002, grad_fn=<AddBackward0>)
# 99000 tensor(0.0002, grad_fn=<AddBackward0>)
# 100000 tensor(0.0003, grad_fn=<AddBackward0>)
# Test RMSE: 0.14313

# %%
'''
import pickle
with open("model_.pickle", "wb") as fp:
    pickle.dump(PINN.state_dict(), fp)
    
with open("points_.pickle", "wb") as fp:
    pickle.dump({"x_t_train":x_train, "x_t_boundary":x_boundary, "u_boundary":u_boundary}, fp)


# Load Model
import pickle
with open("model.pickle", "rb") as fp:
    PINN.load_state_dict(pickle.load(fp))
    
with open("points.pickle", "rb") as fp:
    points = pickle.load(fp)
    x_train = points["x_t_train"]
    x_boundary = points["x_t_boundary"]
    u_boundary = points["u_boundary"]
'''
# Out:
# '\nimport pickle\nwith open("model_.pickle", "wb") as fp:\n    pickle.dump(PINN.state_dict(), fp)\n    \nwith open("points_.pickle", "wb") as fp:\n    pickle.dump({"x_t_train":x_train, "x_t_boundary":x_boundary, "u_boundary":u_boundary}, fp)\n\n\n# Load Model\nimport pickle\nwith open("model.pickle", "rb") as fp:\n    PINN.load_state_dict(pickle.load(fp))\n    \nwith open("points.pickle", "rb") as fp:\n    points = pickle.load(fp)\n    x_train = points["x_t_train"]\n    x_boundary = points["x_t_boundary"]\n    u_boundary = points["u_boundary"]\n'

# %%
''' k=1 '''
x_adv = generate_attack_samples(PINN, device, x_train, N0, n_samples=500)
for i in range(10):
    retrain(PINN, optimizer, x_train, x_adv, x_boundary, u_boundary, x_test, u_test, U_gt, epoch=2e5)
# Out:
# 1000 tensor(0.0114, grad_fn=<AddBackward0>)
# 2000 tensor(0.0086, grad_fn=<AddBackward0>)
# 3000 tensor(0.0072, grad_fn=<AddBackward0>)
# 4000 tensor(0.0066, grad_fn=<AddBackward0>)
# 5000 tensor(0.0063, grad_fn=<AddBackward0>)
# 6000 tensor(0.0061, grad_fn=<AddBackward0>)
# 7000 tensor(0.0061, grad_fn=<AddBackward0>)
# 8000 tensor(0.0057, grad_fn=<AddBackward0>)
# 9000 tensor(0.0056, grad_fn=<AddBackward0>)
# 10000 tensor(0.0053, grad_fn=<AddBackward0>)
# Test RMSE: 0.39161
# 1000 tensor(0.0036, grad_fn=<AddBackward0>)
# 2000 tensor(0.0035, grad_fn=<AddBackward0>)
# 3000 tensor(0.0028, grad_fn=<AddBackward0>)
# 4000 tensor(0.0029, grad_fn=<AddBackward0>)
# 5000 tensor(0.0025, grad_fn=<AddBackward0>)
# 6000 tensor(0.0031, grad_fn=<AddBackward0>)
# 7000 tensor(0.0023, grad_fn=<AddBackward0>)
# 8000 tensor(0.0021, grad_fn=<AddBackward0>)
# 9000 tensor(0.0020, grad_fn=<AddBackward0>)
# 10000 tensor(0.0018, grad_fn=<AddBackward0>)
# Test RMSE: 0.36769
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 x_adv = generate_attack_samples(PINN, device, x_train, N0, n_samples=500)
#       3 for i in range(10):
# ----> 4     retrain(PINN, optimizer, x_train, x_adv, x_boundary, u_boundary, x_test, u_test, U_gt, epoch=1e4)
#
# Cell In[2], line 28, in retrain(model, optimizer, x_train, x_adv, x_boundary, u_boundary, x_test, u_test, U_gt, epoch)
#      25 plot_u(f_test_pred.reshape(X.shape).T, x, t, log=True, title="test $r(x;theta)$")
#      27 model.iter = 0
# ---> 28 model.train_model_adam(optimizer, x_boundary, u_boundary, x_train_temp, epoch)
#      30 rmse, u_pred = model.test(x_test, u_test)
#      31 print('Test RMSE: %.5f'  % (rmse))
#
# File ~/Git/AAAS-PINN/Burgers/main.py:120, in sequential_model.train_model_adam(self, optimizer, x_boundary, u_boundary, x_train, n_epoch)
#     118 while self.iter < n_epoch:
#     119     optimizer.zero_grad()
# --> 120     loss = self.loss(x_boundary, u_boundary, x_train)
#     121     loss.backward()
#     122     self.iter += 1
#
# File ~/Git/AAAS-PINN/Burgers/main.py:111, in sequential_model.loss(self, x_boundary, u_boundary, x)
#     108 if torch.is_tensor(u_boundary) != True:
#     109     u_boundary = torch.from_numpy(u_boundary).float().to(self.device)
# --> 111 f = self.function(x)
#     113 loss_u = self.loss_BC(x_boundary, u_boundary)
#     114 loss_f = self.loss_PDE(f)
#
# File ~/Git/AAAS-PINN/Burgers/main.py:85, in sequential_model.function(self, x)
#      82 g.requires_grad = True
#      84 u = self.forward(g)
# ---> 85 u_xt = autograd.grad(u,g,torch.ones([x.shape[0], 1]).to(self.device), retain_graph=True, create_graph=True)[0]
#      86 u_xxtt = autograd.grad(u_xt,g,torch.ones(x.shape).to(self.device), create_graph=True)[0]
#      88 u_x = u_xt[:,[0]]
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/torch/autograd/__init__.py:202, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     199 if retain_graph is None:
#     200     retain_graph = create_graph
# --> 202 return Variable._execution_engine.run_backward(
#     203     outputs, grad_outputs_, retain_graph, create_graph,
#     204     inputs, allow_unused)
#
# KeyboardInterrupt:

# %%
''' k=2 '''
x_train = np.vstack([x_train, x_adv])
x_adv = generate_attack_samples(PINN, device, x_train, N0)
retrain(PINN, optimizer, x_train, x_adv, x_boundary, u_boundary, x_test, u_test, U_gt)

# %%
''' k=3 '''
x_train = np.vstack([x_train, x_adv])
x_adv = generate_attack_samples(PINN, device, x_train, N0)
retrain(PINN, optimizer, x_train, x_adv, x_boundary, u_boundary, x_test, u_test, U_gt)

# %%
f_adv_pred = np.abs(PINN.function(x_train).squeeze().cpu().detach().numpy())
plot_samples(x_train, f_adv_pred)
