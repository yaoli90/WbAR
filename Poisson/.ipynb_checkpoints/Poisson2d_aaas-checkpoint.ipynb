# %%
import numpy as np
import torch

from visualization import *
from main import *
from used_attacks import regression_PGD

''' Settings and seeds '''

#Set default dtype to float32
torch.set_default_dtype(torch.float)

#PyTorch random number generator
torch.manual_seed(1234)

# Random number generators in other libraries
np.random.seed(1234)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("device:", device)

if device == 'cuda': 
    print(torch.cuda.get_device_name()) 
    
''' test dataset '''
def poisson2d_gt(x,y):
    return np.exp(-np.square(10*x-8)) - np.exp(-np.square(10*y-8)) +\
        np.exp(-np.square(10*x+8)) - np.exp(-np.square(10*y+8)) +\
        np.exp(-np.square(10*x)) - np.exp(-np.square(10*y))

x = np.linspace(-1, 1, 256)
y = np.linspace(-1, 1, 256)
X, Y = np.meshgrid(x,y)
U_gt = poisson2d_gt(X, Y)

x_test = np.hstack((X.flatten()[:,None], Y.flatten()[:,None]))
u_test = U_gt.flatten()[:,None]
print("test dataset:", x_test.shape, '\n')

''' model '''

layers = np.array([2,20,20,20,20,20,20,20,20,1]) #8 hidden layers
PINN = sequential_model(layers, device)
PINN.to(device)
print(PINN)
plot_u(U_gt, x, y, title="$u(x)$")
# Out:
# device: cpu
# test dataset: (65536, 2)
#
# sequential_model(
#   (activation): Tanh()
#   (loss_function): MSELoss()
#   (linears): ModuleList(
#     (0): Linear(in_features=2, out_features=20, bias=True)
#     (1): Linear(in_features=20, out_features=20, bias=True)
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Linear(in_features=20, out_features=20, bias=True)
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Linear(in_features=20, out_features=20, bias=True)
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Linear(in_features=20, out_features=20, bias=True)
#     (8): Linear(in_features=20, out_features=1, bias=True)
#   )
# )
# <AxesSubplot: title={'center': '$u(x)$'}, xlabel='$y$', ylabel='$x$'>

# %%
def generate_attack_samples(model, device, x_train, N0, n_samples=1000, \
    lb=[-1,-1], ub=[1,1], steps=20, eps=1e-1, eta=2e-2, m=1):
    
    attack = regression_PGD(model, lb=lb, ub=ub, steps=steps, eps=eps, eta=eta)
    x_adv = attack.attack(x_train).cpu().detach().numpy()
    
    if x_adv.shape[0] > N0 + (m+1)*n_samples:
        x_adv = np.vstack([x_adv[:N0,:] ,x_adv[-(m+1)*n_samples:,:]])

    f_adv_pred = np.abs(model.function(x_adv).squeeze().cpu().detach().numpy())
    index = np.argsort(f_adv_pred)[::-1][:n_samples]
    x_adv = x_adv[index,:]
    f_adv_pred = f_adv_pred[index]
    
    plot_samples(x_adv, f_adv_pred)
    
    return x_adv


def retrain(model, x_train, x_adv, x_boundary, u_boundary, x_test, u_test, U_gt, epoch=1e5):
    
    f_test_pred = np.abs(PINN.function(x_test).squeeze().cpu().detach().numpy())
    plot_u(f_test_pred.reshape(X.shape).T, x, y, log=True, title="test $r(x;theta)$")

    model.iter = 0
    optimizer = torch.optim.Adam(PINN.parameters(), lr=0.0001)
    model.train_model_adam(optimizer, x_boundary, u_boundary, np.vstack([x_train, x_adv]), epoch)
                           
    rmse, u_pred = model.test(x_test, u_test)
    print('Test RMSE: %.5f'  % (rmse))
                           
    plot_u_x(u_pred.reshape(X.shape).T, U_gt, x, y)
    plot_u(np.abs(u_pred.reshape(X.shape).T-U_gt), x, y, log=True, title="$|u(x;theta)-u(x)|$")

# %%
''' k=0 '''
N0 = 500
x_train, x_boundary, u_boundary = training_data_latin_hypercube(X, Y, U_gt, N_inner=N0)
retrain(PINN, x_train, np.array([]).reshape((0,2)), x_boundary, u_boundary, x_test, u_test, U_gt, epoch=2e5)
# Out:
# 1000 tensor(8061.7876, grad_fn=<AddBackward0>)
# 2000 tensor(7525.9961, grad_fn=<AddBackward0>)
# 3000 tensor(6678.9746, grad_fn=<AddBackward0>)
# 4000 tensor(5800.6611, grad_fn=<AddBackward0>)
# 5000 tensor(5293.1519, grad_fn=<AddBackward0>)
# 6000 tensor(4896.7300, grad_fn=<AddBackward0>)
# 7000 tensor(4578.1968, grad_fn=<AddBackward0>)
# 8000 tensor(3834.8237, grad_fn=<AddBackward0>)
# 9000 tensor(3559.9788, grad_fn=<AddBackward0>)
# 10000 tensor(3341.2002, grad_fn=<AddBackward0>)
# 11000 tensor(3173.5408, grad_fn=<AddBackward0>)
# 12000 tensor(3043.4163, grad_fn=<AddBackward0>)
# 13000 tensor(2919.6853, grad_fn=<AddBackward0>)
# 14000 tensor(2810.6453, grad_fn=<AddBackward0>)
# 15000 tensor(2725.5525, grad_fn=<AddBackward0>)
# 16000 tensor(2638.8284, grad_fn=<AddBackward0>)
# 17000 tensor(2553.7874, grad_fn=<AddBackward0>)
# 18000 tensor(2452.5864, grad_fn=<AddBackward0>)
# 19000 tensor(2277.6970, grad_fn=<AddBackward0>)
# 20000 tensor(1899.1493, grad_fn=<AddBackward0>)
# Test RMSE: 4.97075

# %%
''' k=1 '''
x_adv = generate_attack_samples(PINN, device, x_train, N0, n_samples=500)
retrain(PINN, x_train, x_adv, x_boundary, u_boundary, x_test, u_test, U_gt, epoch=5e4)
# Out:
# 1000 tensor(7090.6904, grad_fn=<AddBackward0>)
# 2000 tensor(4529.7837, grad_fn=<AddBackward0>)
# 3000 tensor(3757.2612, grad_fn=<AddBackward0>)
# 4000 tensor(3253.7563, grad_fn=<AddBackward0>)
# 5000 tensor(2745.1545, grad_fn=<AddBackward0>)
# 6000 tensor(2065.7417, grad_fn=<AddBackward0>)
# 7000 tensor(1619.9768, grad_fn=<AddBackward0>)
# 8000 tensor(1247.6143, grad_fn=<AddBackward0>)
# 9000 tensor(878.3958, grad_fn=<AddBackward0>)
# 10000 tensor(664.7070, grad_fn=<AddBackward0>)
# 11000 tensor(575.4922, grad_fn=<AddBackward0>)
# 12000 tensor(514.8495, grad_fn=<AddBackward0>)
# 13000 tensor(468.6429, grad_fn=<AddBackward0>)
# 14000 tensor(420.9188, grad_fn=<AddBackward0>)
# 15000 tensor(381.0014, grad_fn=<AddBackward0>)
# 16000 tensor(337.8367, grad_fn=<AddBackward0>)
# 17000 tensor(286.9885, grad_fn=<AddBackward0>)
# 18000 tensor(246.1813, grad_fn=<AddBackward0>)
# 19000 tensor(217.9482, grad_fn=<AddBackward0>)
# 20000 tensor(196.0630, grad_fn=<AddBackward0>)
# 21000 tensor(179.5168, grad_fn=<AddBackward0>)
# 22000 tensor(164.0313, grad_fn=<AddBackward0>)
# 23000 tensor(152.9223, grad_fn=<AddBackward0>)
# 24000 tensor(143.7032, grad_fn=<AddBackward0>)
# 25000 tensor(135.6834, grad_fn=<AddBackward0>)
# 26000 tensor(128.6630, grad_fn=<AddBackward0>)
# 27000 tensor(121.9078, grad_fn=<AddBackward0>)
# 28000 tensor(116.3672, grad_fn=<AddBackward0>)
# 29000 tensor(112.4395, grad_fn=<AddBackward0>)
# 30000 tensor(106.4350, grad_fn=<AddBackward0>)
# 31000 tensor(102.4180, grad_fn=<AddBackward0>)
# 32000 tensor(98.5784, grad_fn=<AddBackward0>)
# 33000 tensor(95.3908, grad_fn=<AddBackward0>)
# 34000 tensor(92.0527, grad_fn=<AddBackward0>)
# 35000 tensor(89.3677, grad_fn=<AddBackward0>)
# 36000 tensor(87.5381, grad_fn=<AddBackward0>)
# 37000 tensor(84.9371, grad_fn=<AddBackward0>)
# 38000 tensor(81.9363, grad_fn=<AddBackward0>)
# 39000 tensor(79.5967, grad_fn=<AddBackward0>)
# 40000 tensor(77.4492, grad_fn=<AddBackward0>)
# 41000 tensor(75.4675, grad_fn=<AddBackward0>)
# 42000 tensor(73.6514, grad_fn=<AddBackward0>)
# 43000 tensor(71.5240, grad_fn=<AddBackward0>)
# 44000 tensor(69.7461, grad_fn=<AddBackward0>)
# 45000 tensor(68.5588, grad_fn=<AddBackward0>)
# 46000 tensor(66.0682, grad_fn=<AddBackward0>)
# 47000 tensor(64.3337, grad_fn=<AddBackward0>)
# 48000 tensor(62.5857, grad_fn=<AddBackward0>)
# 49000 tensor(60.9902, grad_fn=<AddBackward0>)
# 50000 tensor(59.3498, grad_fn=<AddBackward0>)
# Test RMSE: 1.84317

# %%
''' k=2:12 '''
for i in range(11):
    x_adv = generate_attack_samples(PINN, device, x_train, N0, n_samples=1000)
    retrain(PINN, x_train, x_adv, x_boundary, u_boundary, x_test, u_test, U_gt, epoch=5e4)
# Out:
# 1000 tensor(553.2314, grad_fn=<AddBackward0>)
# 2000 tensor(344.4808, grad_fn=<AddBackward0>)
# 3000 tensor(258.6742, grad_fn=<AddBackward0>)
# 4000 tensor(207.5552, grad_fn=<AddBackward0>)
# 5000 tensor(176.4633, grad_fn=<AddBackward0>)
# 6000 tensor(154.6524, grad_fn=<AddBackward0>)
# 7000 tensor(138.2995, grad_fn=<AddBackward0>)
# 8000 tensor(127.0598, grad_fn=<AddBackward0>)
# 9000 tensor(114.8150, grad_fn=<AddBackward0>)
# 10000 tensor(106.6462, grad_fn=<AddBackward0>)
# 11000 tensor(98.4219, grad_fn=<AddBackward0>)
# 12000 tensor(92.4348, grad_fn=<AddBackward0>)
# 13000 tensor(86.6039, grad_fn=<AddBackward0>)
# 14000 tensor(80.7666, grad_fn=<AddBackward0>)
# 15000 tensor(76.2976, grad_fn=<AddBackward0>)
# 16000 tensor(72.9069, grad_fn=<AddBackward0>)
# 17000 tensor(69.9405, grad_fn=<AddBackward0>)
# 18000 tensor(65.3750, grad_fn=<AddBackward0>)
# 19000 tensor(62.3588, grad_fn=<AddBackward0>)
# 20000 tensor(59.6659, grad_fn=<AddBackward0>)
# 21000 tensor(57.1274, grad_fn=<AddBackward0>)
# 22000 tensor(54.8167, grad_fn=<AddBackward0>)
# 23000 tensor(52.6943, grad_fn=<AddBackward0>)
# 24000 tensor(50.8946, grad_fn=<AddBackward0>)
# 25000 tensor(48.9696, grad_fn=<AddBackward0>)
# 26000 tensor(47.3263, grad_fn=<AddBackward0>)
# 27000 tensor(45.8456, grad_fn=<AddBackward0>)
# 28000 tensor(44.1511, grad_fn=<AddBackward0>)
# 29000 tensor(45.3981, grad_fn=<AddBackward0>)
# 30000 tensor(41.3560, grad_fn=<AddBackward0>)
# 31000 tensor(40.3534, grad_fn=<AddBackward0>)
# 32000 tensor(39.0370, grad_fn=<AddBackward0>)
# 33000 tensor(39.3451, grad_fn=<AddBackward0>)
# 34000 tensor(38.4837, grad_fn=<AddBackward0>)
# 35000 tensor(35.8183, grad_fn=<AddBackward0>)
# 36000 tensor(35.3866, grad_fn=<AddBackward0>)
# 37000 tensor(34.0510, grad_fn=<AddBackward0>)
# 38000 tensor(33.0642, grad_fn=<AddBackward0>)
# 39000 tensor(32.2648, grad_fn=<AddBackward0>)
# 40000 tensor(33.6408, grad_fn=<AddBackward0>)
# 41000 tensor(30.7201, grad_fn=<AddBackward0>)
# 42000 tensor(30.0032, grad_fn=<AddBackward0>)
# 43000 tensor(29.3122, grad_fn=<AddBackward0>)
# 44000 tensor(30.9381, grad_fn=<AddBackward0>)
# 45000 tensor(30.4073, grad_fn=<AddBackward0>)
# 46000 tensor(27.5282, grad_fn=<AddBackward0>)
# 47000 tensor(26.9100, grad_fn=<AddBackward0>)
# 48000 tensor(26.2998, grad_fn=<AddBackward0>)
# 49000 tensor(25.9748, grad_fn=<AddBackward0>)
# 50000 tensor(25.2163, grad_fn=<AddBackward0>)
# Test RMSE: 1.86308
# 1000 tensor(423.5923, grad_fn=<AddBackward0>)
# 2000 tensor(234.4572, grad_fn=<AddBackward0>)
# 3000 tensor(160.6553, grad_fn=<AddBackward0>)
# 4000 tensor(121.7452, grad_fn=<AddBackward0>)
# 5000 tensor(98.4339, grad_fn=<AddBackward0>)
# 6000 tensor(82.3921, grad_fn=<AddBackward0>)
# 7000 tensor(69.5401, grad_fn=<AddBackward0>)
# 8000 tensor(59.9108, grad_fn=<AddBackward0>)
# 9000 tensor(52.5959, grad_fn=<AddBackward0>)
# 10000 tensor(47.2738, grad_fn=<AddBackward0>)
# 11000 tensor(42.8196, grad_fn=<AddBackward0>)
# 12000 tensor(39.2949, grad_fn=<AddBackward0>)
# 13000 tensor(37.1320, grad_fn=<AddBackward0>)
# 14000 tensor(33.8735, grad_fn=<AddBackward0>)
# 15000 tensor(31.3938, grad_fn=<AddBackward0>)
# 16000 tensor(29.3953, grad_fn=<AddBackward0>)
# 17000 tensor(27.6575, grad_fn=<AddBackward0>)
# 18000 tensor(26.0383, grad_fn=<AddBackward0>)
# 19000 tensor(24.8004, grad_fn=<AddBackward0>)
# 20000 tensor(23.5855, grad_fn=<AddBackward0>)
# 21000 tensor(22.2269, grad_fn=<AddBackward0>)
# 22000 tensor(21.2045, grad_fn=<AddBackward0>)
# 23000 tensor(20.2773, grad_fn=<AddBackward0>)
# 24000 tensor(19.4320, grad_fn=<AddBackward0>)
# 25000 tensor(21.7370, grad_fn=<AddBackward0>)
# 26000 tensor(18.0174, grad_fn=<AddBackward0>)
# 27000 tensor(17.3064, grad_fn=<AddBackward0>)
# 28000 tensor(16.7103, grad_fn=<AddBackward0>)
# 29000 tensor(16.1672, grad_fn=<AddBackward0>)
# 30000 tensor(15.6391, grad_fn=<AddBackward0>)
# 31000 tensor(16.0044, grad_fn=<AddBackward0>)
# 32000 tensor(14.7185, grad_fn=<AddBackward0>)
# 33000 tensor(14.3044, grad_fn=<AddBackward0>)
# 34000 tensor(13.8981, grad_fn=<AddBackward0>)
# 35000 tensor(13.6721, grad_fn=<AddBackward0>)
# 36000 tensor(13.2298, grad_fn=<AddBackward0>)
# 37000 tensor(12.9709, grad_fn=<AddBackward0>)
# 38000 tensor(12.6232, grad_fn=<AddBackward0>)
# 39000 tensor(12.2835, grad_fn=<AddBackward0>)
# 40000 tensor(13.6684, grad_fn=<AddBackward0>)
# 41000 tensor(11.7090, grad_fn=<AddBackward0>)
# 42000 tensor(12.5808, grad_fn=<AddBackward0>)
# 43000 tensor(11.4066, grad_fn=<AddBackward0>)
# 44000 tensor(10.9982, grad_fn=<AddBackward0>)
# 45000 tensor(10.9054, grad_fn=<AddBackward0>)
# 46000 tensor(10.5733, grad_fn=<AddBackward0>)
# 47000 tensor(10.4101, grad_fn=<AddBackward0>)
# 48000 tensor(10.1935, grad_fn=<AddBackward0>)
# 49000 tensor(10.0173, grad_fn=<AddBackward0>)
# 50000 tensor(9.8349, grad_fn=<AddBackward0>)
# Test RMSE: 1.76564
# 1000 tensor(124.5303, grad_fn=<AddBackward0>)
# 2000 tensor(66.5384, grad_fn=<AddBackward0>)
# 3000 tensor(46.8981, grad_fn=<AddBackward0>)
# 4000 tensor(37.2460, grad_fn=<AddBackward0>)
# 5000 tensor(30.9778, grad_fn=<AddBackward0>)
# 6000 tensor(28.7539, grad_fn=<AddBackward0>)
# 7000 tensor(24.9046, grad_fn=<AddBackward0>)
# 8000 tensor(23.2995, grad_fn=<AddBackward0>)
# 9000 tensor(20.8549, grad_fn=<AddBackward0>)
# 10000 tensor(19.5712, grad_fn=<AddBackward0>)
# 11000 tensor(18.1465, grad_fn=<AddBackward0>)
# 12000 tensor(17.0989, grad_fn=<AddBackward0>)
